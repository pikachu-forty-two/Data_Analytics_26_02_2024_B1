# %%
import pandas as pd

# %%
data = pd.read_csv('/content/employee_data.csv')

# %%
data.head()
# Out:
#    employee_id  Gender remarks
# 0            1    Male    Nice
# 1            2  Female    Good
# 2            3    Male   Great
# 3            4  Female    Nice
# 4            5    Male    Good

# %%
data['remarks'].unique()
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
ecoded_data= pd.get_dummies(data, columns=['Gender','remarks'])

# %%
print("Encoded Data:",ecoded_data)
# Out:
# Encoded Data:      employee_id  Gender_Female  Gender_Male  remarks_Good  remarks_Great  \
# 0              1              0            1             0              0
# 1              2              1            0             1              0
# 2              3              0            1             0              1
# 3              4              1            0             0              0
# 4              5              0            1             1              0
# ..           ...            ...          ...           ...            ...
# 247          248              1            0             0              0
# 248          249              0            1             1              0
# 249          250              1            0             0              1
# 250          251              0            1             0              0
# 251          252              1            0             1              0
#
#      remarks_Nice
# 0               1
# 1               0
# ...

# %%
print(ecoded_data.head())
# Out:
#    employee_id  Gender_Female  Gender_Male  remarks_Good  remarks_Great  \
# 0            1              0            1             0              0
# 1            2              1            0             1              0
# 2            3              0            1             0              1
# 3            4              1            0             0              0
# 4            5              0            1             1              0
#
#    remarks_Nice
# 0             1
# 1             0
# 2             0
# 3             1
# 4             0

# %%
ecoded_data.head()
# Out:
#    employee_id  Gender_Female  Gender_Male  remarks_Good  remarks_Great  \
# 0            1              0            1             0              0
# 1            2              1            0             1              0
# 2            3              0            1             0              1
# 3            4              1            0             0              0
# 4            5              0            1             1              0
#
#    remarks_Nice
# 0             1
# 1             0
# 2             0
# 3             1
# 4             0
